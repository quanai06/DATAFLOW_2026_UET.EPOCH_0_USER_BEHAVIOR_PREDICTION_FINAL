# %%
import pandas as pd 
orders=pd.read_parquet(r'/home/quan/DATAFLOW_2026_UET.EPOCH_0_USER_BEHAVIOR_PREDICTION_FINAL/data/precomputed_orders.parquet')

# %%
orders.head(20)
# Out:
#        id                                       raw_sequence  sequence_length  \
# 0   n6r61  [609, 1433, 709, 25824, 613, 108, 929, 3115, 6...               32
# 1   jkctd  [609, 1433, 610, 883, 606, 2646, 613, 775, 907...               19
# 2   a4060  [609, 1433, 1338, 621, 3114, 4507, 4275, 605, ...               14
# 3   fkbud  [1338, 621, 12516, 5451, 4521, 2669, 102, 1016...               37
# 4   ui5gu  [26738, 613, 4425, 1243, 1265, 117, 603, 2137,...               16
# 5   g8ktx  [630, 15030, 1693, 613, 106, 4822, 1243, 2581,...               21
# 6   mj2pa                                  [4089, 103, 4787]                3
# 7   j2di9  [26738, 613, 775, 113, 1455, 117, 603, 2137, 8...               16
# 8   wuozj  [621, 714, 4706, 113, 4275, 606, 714, 4347, 11...               10
# 9   l83u3  [760, 1165, 15881, 975, 103, 12516, 5451, 2027...                9
# 10  e21yw    [979, 102, 907, 775, 103, 4556, 102, 4275, 113]                9
# ...
